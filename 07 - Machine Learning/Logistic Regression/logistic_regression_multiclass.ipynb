# %% [markdown]
# # 🛡️ Cyber Attack Type Classification - Multiclass Logistic Regression
#
# **🇹🇷 Türkçe:**
# Bu projede, siber saldırı verilerini (`7-cyber_attack_data.csv`) inceleyerek ağ trafiği özelliklerine dayalı siber saldırı türlerini (`attack_type`) sınıflandırıyoruz[cite: 7]. İkiden fazla sınıfımız olduğu için Çok Sınıflı Sınıflandırma (Multiclass Classification) stratejilerini uygulayacağız[cite: 7].
#
# **🇬🇧 English:**
# In this project, we analyze cyber attack data (`7-cyber_attack_data.csv`) to classify cyber attack types (`attack_type`) based on network traffic features[cite: 7]. Since we have more than two classes, we will apply Multiclass Classification strategies[cite: 7].

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../../Data/7-cyber_attack_data.csv")

# %%
df.columns
# Out:
# Index(['src_packet_rate', 'dst_packet_rate', 'avg_payload_size',
#        'connection_duration', 'tcp_flag_count', 'avg_interarrival_time',
#        'failed_login_attempts', 'unusual_port_activity_score',
#        'session_entropy', 'avg_response_delay', 'attack_type'],
#       dtype='str')

# %%
df.head()
# Out:
#    src_packet_rate  dst_packet_rate  avg_payload_size  connection_duration  \
# 0        -1.286132        -0.648334          1.044115            -0.469715
# 1        -0.222224         2.083232          1.191114            -1.354527
# 2        -0.431963         0.375745         -1.370334             0.819214
# 3        -0.912633         0.986988         -0.690042             2.014628
# 4        -0.367056         1.667892          0.879172             2.214276
#
#    tcp_flag_count  avg_interarrival_time  failed_login_attempts  \
# 0        0.789859              -0.083727              -1.647309
# 1       -0.956992               1.696028              -1.070406
# 2        0.345243               1.389447              -1.904130
# 3       -0.442260               0.590347              -1.819353
# 4        1.846338              -0.894047               1.543838
#
#    unusual_port_activity_score  session_entropy  avg_response_delay  \
# ...

# %% [markdown]
# ## ⚙️ Veri Ayırma İşlemi / Data Splitting
#
# **🇹🇷 Türkçe:**
# Hedef değişkenimiz olan `attack_type` (saldırı türü) sütununu özelliklerden (features) ayırıyoruz[cite: 7]. Ardından modelin performansını daha sonra ölçebilmek için verimizi Eğitim (Train) ve Test setlerine bölüyoruz[cite: 7].
#
# **🇬🇧 English:**
# We separate our target variable `attack_type` from the features[cite: 7]. Then, we split our data into Training and Test sets to evaluate the model's performance later[cite: 7].

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop("attack_type",axis=1)
y = df["attack_type"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 15)

# %% [markdown]
# ## 🤖 Standart Lojistik Regresyon / Default Logistic Regression
#
# **🇹🇷 Türkçe:**
# Standart bir Lojistik Regresyon (Logistic Regression) modeli oluşturup eğitim verilerimiz üzerinde eğitiyoruz[cite: 7]. Sonrasında Doğruluk (Accuracy) ve Karmaşıklık Matrisi (Confusion Matrix) metrikleriyle model performansımızı analiz ediyoruz[cite: 7].
#
# **🇬🇧 English:**
# We instantiate a standard Logistic Regression model and train it on our training data[cite: 7]. Afterwards, we analyze our model performance using Accuracy and Confusion Matrix metrics[cite: 7].

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic = LogisticRegression()

# %%
logistic.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logistic.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
accuracy = accuracy_score(y_pred, y_test)
cm = confusion_matrix(y_pred, y_test)

# %%
print(accuracy)
print(cm)
# Out:
# 0.7866666666666666
# [[82  2  6]
#  [17 72 10]
#  [ 6 23 82]]

# %% [markdown]
# ## 🔄 Çok Sınıflı Sınıflandırma Stratejileri / Multiclass Classification Strategies
#
# **🇹🇷 Türkçe:**
# Lojistik Regresyon ikili (binary) bir sınıflandırıcı olduğu için, üç farklı saldırı türünü sınıflandırırken `OneVsOneClassifier` (Bire Karşı Bir) ve `OneVsRestClassifier` (Bire Karşı Hepsi) stratejilerini deniyoruz[cite: 7]. Bu yöntemler, modelin doğruluğunu optimize etmemize yardımcı olur[cite: 7].
#
# **🇬🇧 English:**
# Since Logistic Regression is a binary classifier, we experiment with `OneVsOneClassifier` and `OneVsRestClassifier` strategies to classify the three different attack types[cite: 7]. These methods help us optimize the accuracy of the model[cite: 7].

# %%
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier

# %%
onevsone = OneVsOneClassifier(LogisticRegression())
onevsrest =OneVsRestClassifier(LogisticRegression())

# %%
onevsrest.fit(X_train, y_train)
y_pred = onevsrest.predict(X_test)
accuracy = accuracy_score(y_pred, y_test)
cm = confusion_matrix(y_pred, y_test)
print(cm)
print(accuracy)
# Out:
# [[83  2  6]
#  [16 69  9]
#  [ 6 26 83]]
# 0.7833333333333333

# %%
onevsone.fit(X_train, y_train)
y_pred = onevsone.predict(X_test)
accuracy = accuracy_score(y_pred, y_test)
cm = confusion_matrix(y_pred, y_test)
print(cm)
print(accuracy)
# Out:
# [[84  3  4]
#  [12 72 11]
#  [ 9 22 83]]
# 0.7966666666666666
