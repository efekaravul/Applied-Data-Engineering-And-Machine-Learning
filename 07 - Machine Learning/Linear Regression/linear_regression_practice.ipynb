# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../../Data/insurance.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[["age","sex","bmi","children","smoker","region"]]
y = df["charges"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 15)

# %%
X_train
# Out:
#       age     sex     bmi  children smoker     region
# 1256   51  female  36.385         3     no  northwest
# 147    51  female  37.730         1     no  southeast
# 1042   20    male  30.685         0    yes  northeast
# 889    57    male  33.630         1     no  northwest
# 650    49  female  42.680         2     no  southeast
# ...   ...     ...     ...       ...    ...        ...
# 1223   20  female  24.420         0    yes  southeast
# 667    40  female  32.775         2    yes  northwest
# 156    48    male  24.420         0    yes  southeast
# 384    44    male  22.135         2     no  northeast
# 645    48    male  30.780         3     no  northeast
#
# [1070 rows x 6 columns]

# %%
X_test
# Out:
#       age     sex    bmi  children smoker     region
# 38     35    male  36.67         1    yes  northeast
# 126    19  female  28.30         0    yes  southwest
# 479    23    male  32.56         0     no  southeast
# 10     25    male  26.22         0     no  northeast
# 195    19    male  30.59         0     no  northwest
# ...   ...     ...    ...       ...    ...        ...
# 1059   32    male  33.82         1     no  northwest
# 303    28  female  33.00         2     no  southeast
# 335    64    male  34.50         0     no  southwest
# 792    22  female  23.18         0     no  northeast
# 1213   52  female  33.30         2     no  southwest
#
# [268 rows x 6 columns]

# %% [markdown]
# data leakage önlemek için encodingleri şimdi yapıcaz

# %%
X_train["sex"] = X_train["sex"].map({"male":0, "female":1})
X_test["sex"] = X_test["sex"].map({"male":0, "female":1})

# %%
X_train
# Out:
#       age  sex     bmi  children smoker     region
# 1256   51    1  36.385         3     no  northwest
# 147    51    1  37.730         1     no  southeast
# 1042   20    0  30.685         0    yes  northeast
# 889    57    0  33.630         1     no  northwest
# 650    49    1  42.680         2     no  southeast
# ...   ...  ...     ...       ...    ...        ...
# 1223   20    1  24.420         0    yes  southeast
# 667    40    1  32.775         2    yes  northwest
# 156    48    0  24.420         0    yes  southeast
# 384    44    0  22.135         2     no  northeast
# 645    48    0  30.780         3     no  northeast
#
# [1070 rows x 6 columns]

# %%
X_train["smoker"] = X_train["smoker"].map({"yes":1, "no":0})
X_test["smoker"] = X_test["smoker"].map({"yes":1, "no":0})

# %%
X_train["region"].unique()
# Out:
# <StringArray>
# ['northwest', 'southeast', 'northeast', 'southwest']
# Length: 4, dtype: str

# %%
X_train = pd.get_dummies(X_train, columns=["region"], drop_first=True, dtype=int)
X_test = pd.get_dummies(X_test, columns=["region"], drop_first=True, dtype=int)

# %%
X_train
# Out:
#       age  sex     bmi  children  smoker  region_northwest  region_southeast  \
# 1256   51    1  36.385         3       0                 1                 0
# 147    51    1  37.730         1       0                 0                 1
# 1042   20    0  30.685         0       1                 0                 0
# 889    57    0  33.630         1       0                 1                 0
# 650    49    1  42.680         2       0                 0                 1
# ...   ...  ...     ...       ...     ...               ...               ...
# 1223   20    1  24.420         0       1                 0                 1
# 667    40    1  32.775         2       1                 1                 0
# 156    48    0  24.420         0       1                 0                 1
# 384    44    0  22.135         2       0                 0                 0
# 645    48    0  30.780         3       0                 0                 0
#
#       region_southwest
# 1256                 0
# 147                  0
# 1042                 0
# 889                  0
# 650                  0
# ...                ...
# 1223                 0
# 667                  0
# 156                  0
# 384                  0
# 645                  0
#
# [1070 rows x 8 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.8143715 ,  1.00938988,  0.92361714, ...,  1.78316783,
#         -0.60254238, -0.57375304],
#        [ 0.8143715 ,  1.00938988,  1.14285117, ..., -0.56079971,
#          1.65963429, -0.57375304],
#        [-1.38518087, -0.99069747, -0.00547876, ..., -0.56079971,
#         -0.60254238, -0.57375304],
#        ...,
#        [ 0.60151159, -0.99069747, -1.02666924, ..., -0.56079971,
#          1.65963429, -0.57375304],
#        [ 0.31769838, -0.99069747, -1.3991226 , ..., -0.56079971,
#         -0.60254238, -0.57375304],
#        [ 0.60151159, -0.99069747,  0.01000618, ..., -0.56079971,
#         -0.60254238, -0.57375304]], shape=(1070, 8))

# %%
X_test
# Out:
# array([[-0.32088134, -0.99069747,  0.97007193, ..., -0.56079971,
#         -0.60254238, -0.57375304],
#        [-1.45613417,  1.00938988, -0.39423204, ..., -0.56079971,
#         -0.60254238,  1.74291017],
#        [-1.17232096, -0.99069747,  0.30014489, ..., -0.56079971,
#          1.65963429, -0.57375304],
#        ...,
#        [ 1.73676442, -0.99069747,  0.6163635 , ..., -0.56079971,
#         -0.60254238,  1.74291017],
#        [-1.24327426,  1.00938988, -1.22878835, ..., -0.56079971,
#         -0.60254238, -0.57375304],
#        [ 0.8853248 ,  1.00938988,  0.42076436, ..., -0.56079971,
#         -0.60254238,  1.74291017]], shape=(268, 8))

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(X_test)

# %%
y_pred
# Out:
# array([33890.21746398, 25233.16770791,  3791.35859501,  3236.48950223,
#         2753.78589644,  8033.19434312,   986.8359004 , 34996.35894003,
#         8442.93273586,  8820.10937347,  3895.51369222,  6211.06335152,
#        35977.64400112, 32768.35404822,  5519.16539467, 37357.53637207,
#        27197.40132169,  9381.17555737, 30153.99797749,  8237.76932057,
#         5443.36483562,  9757.7881789 ,  3380.6687726 , 18562.02604072,
#        11847.3988793 ,  8691.27557737,  7683.21386456, 39069.50138105,
#         3714.68510187,   -48.3377788 ,  6882.26406994,  9270.97591921,
#         5484.24601192, 41119.11931005,  6971.11105692,  5577.71534461,
#         5458.22851457,  3827.22533323,  6328.95680314, 11561.51731191,
#         7167.25740263, 10780.62087794, 15750.70435474,  2725.46683683,
#        11149.61900748, 11239.45478649, 11669.62825239,  6451.20447244,
#         9674.10638387, 28654.83352765,  1286.48507399,  2157.91909444,
#         9004.72207652, 10266.46054073, 12935.60069719, 26766.68773927,
#         1042.92582197, 12366.93775239,  4976.87549627, 15609.85496623,
#         6432.66018984, 30690.92700587, 25071.99351563,  5494.8291568 ,
#        34375.35533166, 36906.95390492,  4987.18735167, 11001.09821612,
#        11498.22536621, 33648.997572  , 10696.95161343,  5159.17983001,
#        10882.81204832, 12252.82698181,   -74.40306279,  7523.19616316,
#        37076.64733819, 13517.57382483, 19199.49024044,  9831.03924706,
#        12733.30097682, 11872.51938623, 39254.48138542,  2360.07422118,
#         7897.91466063, 29903.90218548, 16091.98391367,  5084.33934863,
