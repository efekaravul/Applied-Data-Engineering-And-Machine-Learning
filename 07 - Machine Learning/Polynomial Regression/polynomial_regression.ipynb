# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv("../../Data/3-customersatisfaction.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Customer Satisfaction  Incentive
# 0           0              -1.282447   1.010513
# 1           1               0.425298   2.281043
# 2           2               1.953070   4.415053
# 3           3               2.625838  10.563600
# 4           4              -1.426333   0.627365

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df.head()
# Out:
#    Customer Satisfaction  Incentive
# 0              -1.282447   1.010513
# 1               0.425298   2.281043
# 2               1.953070   4.415053
# 3               2.625838  10.563600
# 4              -1.426333   0.627365

# %%
plt.scatter(df["Customer Satisfaction"], df["Incentive"], color = "yellow")
plt.xlabel("Customer Satisfaction")
plt.ylabel("Incentive")
plt.show()

# %%
# train-test-split

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
X
# Out:
#     Customer Satisfaction
# 0               -1.282447
# 1                0.425298
# 2                1.953070
# 3                2.625838
# 4               -1.426333
# ..                    ...
# 95               2.055072
# 96               0.864149
# 97              -1.586101
# 98               1.558528
# 99               0.512504
#
# [100 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 15)

# %%
X_train
# Out:
#     Customer Satisfaction
# 99               0.512504
# 3                2.625838
# 20              -0.865714
# 55              -1.145369
# 6                2.823460
# ..                    ...
# 28               1.191020
# 0               -1.282447
# 5               -1.311432
# 12               0.490521
# 72              -2.243889
#
# [80 rows x 1 columns]

# %%
#standart scale

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
regression = LinearRegression()

# %%
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(X_test)

# %%
score = r2_score(y_test, y_pred)
print(score)
# Out:
# 0.2705652535622246

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regression.predict(X_train), color = 'blue')
plt.show()

# %% [markdown]
# Linear regression burada işe yaramıyor

# %%
poly = PolynomialFeatures(degree = 2)

# %%
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
regression = LinearRegression()

# %%
regression.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(X_test_poly)
r2_score(y_test, y_pred)
# Out:
# 0.7685687698788557

# %%
print(r2_score(y_test, y_pred))
# Out:
# 0.7685687698788557

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.scatter(X_train, regression.predict(X_train_poly), color = 'blue')
plt.show()

# %%
new_df = pd.read_csv("../../Data/3-newdatas.csv")

# %%
new_df.head()
# Out:
#           0
# 0 -3.000000
# 1 -2.969849
# 2 -2.939698
# 3 -2.909548
# 4 -2.879397

# %%
new_df.rename(columns={"0": "New Customer Satisfaction"}, inplace=True)

# %%
new_df
# Out:
#      New Customer Satisfaction
# 0                    -3.000000
# 1                    -2.969849
# 2                    -2.939698
# 3                    -2.909548
# 4                    -2.879397
# ..                         ...
# 195                   2.879397
# 196                   2.909548
# 197                   2.939698
# 198                   2.969849
# 199                   3.000000
#
# [200 rows x 1 columns]

# %%
X_new = new_df[["New Customer Satisfaction"]]

# %%
X_new = scaler.fit_transform(X_new)

# %%
X_new_poly = poly.transform(X_new)

# %%
y_new = regression.predict(X_new_poly)

# %%
plt.plot(X_new, y_new, color = 'red', label = "New Pred")
plt.scatter(X_train, y_train, color = 'blue', label = "Training Data")
plt.show()

# %%
#pipeline

# %%
def poly_regression(degree):
    poly_features = PolynomialFeatures(degree = degree)
    lin_reg = LinearRegression()
    pipeline = Pipeline([
        ("standard_scaler", scaler),
        ("poly_features", poly_features),
        ("lin_reg", lin_reg)]
    )
    pipeline.fit(X_train, y_train)
    score = pipeline.score(X_test, y_test)
    print(score)

# %%
for degree in [1,2,3,4,5,6,7,8,9]:
    poly_regression(degree)
# Out:
# 0.2705652535622246
# 0.7685687698788558
# 0.757344362140105
# 0.7355034443260414
# 0.7351244165095401
# 0.7343590482133427
# 0.7347819263549451
# 0.7411422099998385
# 0.7310763879815914
