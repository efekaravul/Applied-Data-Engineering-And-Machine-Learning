# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
age_list = [10,20,30,30,30,40,60,70,75]
weight_list = [20,60,80,85,86,87,70,90,95]

plt.plot(age_list,weight_list, "y")
plt.xlabel("Age")
plt.ylabel("Weight")
plt.show()
